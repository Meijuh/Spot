# %%
from IPython.display import display 
import spot
spot.setup()

# %% [markdown]
# # Reading automata output from processes
#
# If an argument of `spot.automata` ends with `|`, then it is interpreted as a shell command that outputs one automaton or more.

# %%
for a in spot.automata('ltl2tgba -s "a U b"; ltl2tgba --lbtt "b"|', 'ltl2tgba -H "GFa" "a & GFb"|'):
    display(a)
# Out:
# <spot_impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f3fa02ed390> >
# <spot_impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f3fa02ed420> >
# <spot_impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f3fa02ed3f0> >
# <spot_impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f3fa02ed390> >

# %% [markdown]
# A single automaton can be read using `spot.automaton()`, with the same convention.

# %%
spot.automaton('ltl2tgba -s6 "a U b"|')
# Out:
# <spot_impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f3fa02ed480> >

# %% [markdown]
# # Error handling
#
# If the shell command terminates with a non-zero exit status, we should get an exception.

# %%
spot.automaton('non-existing-command|')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-765c7cc6937f> in <module>()
# ----> 1 spot.automaton('non-existing-command|')
#
# /home-ssd/adl/git/spot/wrap/python/spot.py in automaton(filename)
#     369     See `spot.automata` for a list of supported formats."""
#     370     try:
# --> 371         return next(automata(filename))
#     372     except StopIteration:
#     373         raise RuntimeError("Failed to read automaton from {}".format(filename))
#
# /home-ssd/adl/git/spot/wrap/python/spot.py in automata(*filenames)
#     360                 if ret:
#     361                     raise RuntimeError("Command {} exited with exit status {}"
# --> 362                                        .format(filename[:-1], ret))
#     363     return
#     364
#
# RuntimeError: Command non-existing-command exited with exit status 127

# %%
for a in spot.automata("ltl2tgba -H 'a U b'|", 'ltl2tgba -f "syntax U U error"|'):
    display(a)
# Out:
# <spot_impl.twa_graph; proxy of <Swig Object of type 'std::shared_ptr< spot::twa_graph > *' at 0x7f3fa02edea0> >
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-21a24ff75c32> in <module>()
# ----> 1 for a in spot.automata("ltl2tgba -H 'a U b'|", 'ltl2tgba -f "syntax U U error"|'):
#       2     display(a)
#
# /home-ssd/adl/git/spot/wrap/python/spot.py in automata(*filenames)
#     360                 if ret:
#     361                     raise RuntimeError("Command {} exited with exit status {}"
# --> 362                                        .format(filename[:-1], ret))
#     363     return
#     364
#
# RuntimeError: Command ltl2tgba -f "syntax U U error" exited with exit status 2

# %% [markdown]
# Reading an empty file with `spot.automaton()` is an error.

# %%
spot.automaton('false|')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-029e1e5901f7> in <module>()
# ----> 1 spot.automaton('false|')
#
# /home-ssd/adl/git/spot/wrap/python/spot.py in automaton(filename)
#     369     See `spot.automata` for a list of supported formats."""
#     370     try:
# --> 371         return next(automata(filename))
#     372     except StopIteration:
#     373         raise RuntimeError("Failed to read automaton from {}".format(filename))
#
# /home-ssd/adl/git/spot/wrap/python/spot.py in automata(*filenames)
#     360                 if ret:
#     361                     raise RuntimeError("Command {} exited with exit status {}"
# --> 362                                        .format(filename[:-1], ret))
#     363     return
#     364
#
# RuntimeError: Command false exited with exit status 1
