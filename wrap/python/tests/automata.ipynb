# %%
import os
# Note that Spot (loaded by the kernel) will store a copy of
# the environment variable the first time it reads them, so
# if you change those variables, the new values will be ignored
# until you restart the kernel.
os.environ['SPOT_DOTEXTRA'] = 'size="10.2,5" node[style=filled,fillcolor="#ffffaa"]'
os.environ['SPOT_DOTDEFAULT'] = 'rbcf(Lato)'
import spot

# %%
a = spot.translate('(a U b) & GFc & GFd', 'BA', complete=True); a
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f5e403071b0> >

# %%
a.show("")

# %%
a.show(".ast")

# %%
f = spot.formula('a U b'); f
# Out:
# a U b

# %%
spot.translate(f)
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f5e4005c9c0> >

# %%
f.translate()
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f5e4005cbd0> >

# %%
f.translate('mon')
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f5e4005ca20> >

# %%
f = spot.formula('Ga | Gb | Gc'); f
# Out:
# Ga | Gb | Gc

# %%
f.translate('ba', 'small').show('v')

# %%
f.translate('ba', 'det').show('v.')

# %%
a = spot.translate('F(a & X(!a &Xb))', pref="any"); a
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f5e4005cc00> >

# %%
spot.sl(a)
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f5e4005c9f0> >
