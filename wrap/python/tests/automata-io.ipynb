# %%
import os
from IPython.display import display
# Note that Spot (loaded by the kernel) will store a copy of
# the environment variables the first time it reads them, so
# if you change those variables, the new values will be ignored
# until you restart the kernel.
os.environ['SPOT_DOTEXTRA'] = 'size="10.2,5" node[style=filled,fillcolor="#ffffaa"] edge[arrowhead=vee, arrowsize=.7]'
os.environ['SPOT_DOTDEFAULT'] = 'rbcf(Lato)'
import spot

# %%
a = spot.translate('a U b')
for fmt in ('hoa', 'spin', 'dot', 'lbtt'):
    print(a.to_str(fmt))
# Out:
# HOA: v1
# States: 2
# Start: 1
# AP: 2 "a" "b"
# acc-name: Buchi
# Acceptance: 1 Inf(0)
# properties: trans-labels explicit-labels state-acc deterministic
# properties: stutter-invariant inherently-weak
# --BODY--
# State: 0 {0}
# [t] 0
# State: 1
# [1] 0
# [0&!1] 1
# --END--
# never {
# T0_init:
#   if
#   :: ((b)) -> goto accept_all
#   :: ((a) && (!(b))) -> goto T0_init
#   fi;
# accept_all:
#   skip
# }
#
# digraph G {
#   rankdir=LR
#   node [shape="circle"]
#   fontname="Lato"
#   node [fontname="Lato"]
#   edge [fontname="Lato"]
#   size="10.2,5" node[style=filled,fillcolor="#ffffaa"] edge[arrowhead=vee, arrowsize=.7]
#   I [label="", style=invis, width=0]
#   I -> 1
#   0 [label=<0<br/><font color="#5DA5DA">⓿</font>>]
#   0 -> 0 [label=<1>]
#   1 [label=<1>]
#   1 -> 0 [label=<b>]
#   1 -> 1 [label=<a &amp; !b>]
# }
#
# 2 1t
# 0 1
# 1 -1 "b"
# 0 -1 & "a" ! "b"
# -1
# 1 0
# 1 0 -1 t
# -1

# %%
a.save('example.aut').save('example.aut', format='lbtt', append=True)
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f48240566f0> >

# %%
# !cat example.aut
# Out:
# HOA: v1
# States: 2
# Start: 1
# AP: 2 "a" "b"
# acc-name: Buchi
# Acceptance: 1 Inf(0)
# properties: trans-labels explicit-labels state-acc deterministic
# properties: stutter-invariant inherently-weak
# --BODY--
# State: 0 {0}
# [t] 0
# State: 1
# [1] 0
# [0&!1] 1
# --END--
# 2 1t
# 0 1
# 1 -1 "b"
# 0 -1 & "a" ! "b"
# -1
# 1 0
# 1 0 -1 t
# -1

# %%
for a in spot.automata('example.aut'):
    display(a)
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f4824056960> >
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f4824056990> >

# %% [markdown]
# Test `--ABORT--`
# ----------------

# %%
# %%file example.aut
# HOA: v1
# States: 2
# Start: 1
# AP: 2 "a" "b"
# acc-name: Buchi
# Acceptance: 1 Inf(0)
# --BODY--
# State: 0 {0}
# [t] 0
# --ABORT--   /* the previous automaton should be ignored */
# HOA: v1
# States: 2
# Start: 1
# AP: 2 "a" "b"
# Acceptance: 1 Inf(0)
# --BODY--
# State: 0 {0}
# [t] 0
# State: 1
# [1] 0
# [0&!1] 1
# --END--
# Out:
# Overwriting example.aut

# %%
for a in spot.automata('example.aut'):
    display(a)
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f4824056ba0> >

# %% [markdown]
# Test syntax errors
# ------------------

# %%
# %%file example.aut
# HOA: v1
# States: 2
# Start: 1
# AP: 2 "a" "b"
# acc-name: Buchi
# Acceptance: 1 Inf(0)
# --BODY--
# State: 0 {0}
# [t] 1
# State: 1
# [t] 1
# --END--
# HOA: v1
# States: 2
# Start: 1
# AP: 2 "a" "b"
# Acceptance: 1 Inf(0)
# --BODY--
# State: 0 {0}
# [a] 3
# State: 1
# [1] 0
# [0&!1] 1
# --END--
# Out:
# Overwriting example.aut

# %%
for a in spot.automata('example.aut'):
    display(a)
# Out:
# <spot_impl.tgba_digraph; proxy of <Swig Object of type 'std::shared_ptr< spot::tgba_digraph > *' at 0x7f4824056d20> >
#   File "<string>", line unknown
# SyntaxError:
# example.aut:20.2: syntax error, unexpected identifier
# example.aut:20.1-3: ignoring this invalid label
# example.aut:20.5: state number is larger than state count...
# example.aut:14.1-9: ... declared here.

# %%
rm example.aut

# %%
spot.automaton('example.aut')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-91499c480122> in <module>()
# ----> 1 spot.automaton('example.aut')
#
# /home/adl/git/spot/wrap/python/spot.py in automaton(filename)
#     179     a = automata(filename)
#     180     try:
# --> 181         return next(a)
#     182     except StopIteration:
#     183         raise RuntimeError("Failed to read automaton from {}".format(filename))
#
# /home/adl/git/spot/wrap/python/spot.py in automata(*filenames)
#     141             if filename[-1] != '|':
#     142                 proc = None
# --> 143                 p = hoa_stream_parser(filename, True)
#     144             else:
#     145                 proc = subprocess.Popen(filename[:-1], shell=True,
#
# /home/adl/git/spot/wrap/python/spot_impl.py in __init__(self, *args)
#    2206     __repr__ = _swig_repr
#    2207     def __init__(self, *args):
# -> 2208         this = _spot_impl.new_hoa_stream_parser(*args)
#    2209         try: self.this.append(this)
#    2210         except: self.this = this
#
# RuntimeError: Cannot open file example.aut

# %%
spot.automaton('non-existing-cmd |')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-12-2b2d1b66dcd6> in <module>()
# ----> 1 spot.automaton('non-existing-cmd |')
#
# /home/adl/git/spot/wrap/python/spot.py in automaton(filename)
#     179     a = automata(filename)
#     180     try:
# --> 181         return next(a)
#     182     except StopIteration:
#     183         raise RuntimeError("Failed to read automaton from {}".format(filename))
#
# /home/adl/git/spot/wrap/python/spot.py in automata(*filenames)
#     170                 if ret:
#     171                     raise RuntimeError("Command {} exited with exit status {}"
# --> 172                                        .format(filename[:-1], ret))
#     173     return
#     174
#
# RuntimeError: Command non-existing-cmd  exited with exit status 127
