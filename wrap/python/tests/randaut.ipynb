# %%
import os
from IPython.display import display, HTML
# Note that Spot (loaded by the kernel) will store a copy of
# the environment variables the first time it reads them, so
# if you change those variables, the new values will be ignored
# until you restart the kernel.
os.environ['SPOT_DOTEXTRA'] = 'size="5,5" node[style=filled,fillcolor="#ffffaa"] edge[arrowhead=vee, arrowsize=.7]'
os.environ['SPOT_DOTDEFAULT'] = 'rbcf(Lato)'
import spot

# %%
txt = "<TABLE><TR><TH>before</TH><TH>after</TH>"
for a in spot.automata('randaut -H -S5 -A 3 -n10 2|'):
    txt += "<TR><TD>{0}</TD><TD>{1}</TD></TR>".format(a.show('.a').data, spot.cleanup_acceptance(a).show('.a').data)
txt += ("</TABLE>")
HTML(txt)
# Out:
# <TABLE><TR><TH>before</TH><TH>after</TH><TR><TD><svg height="83pt" viewBox="0.00 0.00 360.00 83.44" width="360pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(0.552571 0.552571) rotate(0) translate(4 147)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-147 647.5,-147 647.5,4 -4,4" stroke="none"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="248.75" y="-128.8">Inf(</text>
# <text fill="#5da5da" font-family="Lato" font-size="14.00" text-anchor="start" x="270.75" y="-128.8">⓿</text>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="286.75" y="-128.8">)&amp;Inf(</text>
# <text fill="#f17cb0" font-family="Lato" font-size="14.00" text-anchor="start" x="322.75" y="-128.8">❶</text>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="338.75" y="-128.8">)&amp;Inf(</text>
# <text fill="#faa43a" font-family="Lato" font-size="14.00" text-anchor="start" x="374.75" y="-128.8">❷</text>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="390.75" y="-128.8">)</text>
# <!-- I -->
# <!-- 0 -->
# <g class="node" id="node2"><title>0</title>
# <ellipse cx="56" cy="-52" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="56" y="-48.3">0</text>
# </g>
# <!-- I&#45;&gt;0 -->
# <g class="edge" id="edge1"><title>I-&gt;0</title>
# <path d="M1.15491,-52C2.79388,-52 17.1543,-52 30.6317,-52" fill="none" stroke="black"/>
# <polygon fill="black" points="37.9419,-52 30.9419,-55.1501 34.4419,-52 30.9419,-52.0001 30.9419,-52.0001 30.9419,-52.0001 34.4419,-52 30.9418,-48.8501 37.9419,-52 37.9419,-52" stroke="black"/>
# </g>
# <!-- 3 -->
# <g class="node" id="node3"><title>3</title>
# <ellipse cx="196.5" cy="-47" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="196.5" y="-43.3">3</text>
# </g>
# <!-- 0&#45;&gt;3 -->
# <g class="edge" id="edge2"><title>0-&gt;3</title>
# <path d="M71.7168,-42.4577C77.7499,-39.083 84.9605,-35.7041 92,-34 117.486,-27.8305 125.042,-30.286 151,-34 158.021,-35.0046 165.482,-36.858 172.247,-38.8569" fill="none" stroke="black"/>
# <polygon fill="black" points="179.262,-41.0496 171.641,-41.9676 175.921,-40.0053 172.581,-38.9611 172.581,-38.9611 172.581,-38.9611 175.921,-40.0053 173.521,-35.9545 179.262,-41.0496 179.262,-41.0496" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="92" y="-37.8">!p0 &amp; !p1</text>
# </g>
# <!-- 3&#45;&gt;0 -->
# <g class="edge" id="edge8"><title>3-&gt;0</title>
# <path d="M178.173,-47.8311C169.941,-48.2126 159.964,-48.6555 151,-49 127.378,-49.9077 100.409,-50.7483 81.4345,-51.3073" fill="none" stroke="black"/>
# <polygon fill="black" points="74.3274,-51.5145 81.2325,-48.1617 77.8259,-51.4125 81.3244,-51.3104 81.3244,-51.3104 81.3244,-51.3104 77.8259,-51.4125 81.4162,-54.4591 74.3274,-51.5145 74.3274,-51.5145" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="94" y="-53.8">p0 &amp; !p1</text>
# </g>
# <!-- 2 -->
# <g class="node" id="node6"><title>2</title>
# <ellipse cx="342.5" cy="-76" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="342.5" y="-72.3">2</text>
# </g>
# <!-- 3&#45;&gt;2 -->
# <g class="edge" id="edge9"><title>3-&gt;2</title>
# <path d="M214.3,-50.3834C239.88,-55.5349 288.69,-65.3647 317.844,-71.236" fill="none" stroke="black"/>
# <polygon fill="black" points="324.807,-72.6381 317.322,-74.3441 321.375,-71.9471 317.944,-71.2561 317.944,-71.2561 317.944,-71.2561 321.375,-71.9471 318.566,-68.1681 324.807,-72.6381 324.807,-72.6381" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="242" y="-69.8">!p0 &amp; p1</text>
# </g>
# <!-- 1 -->
# <g class="node" id="node4"><title>1</title>
# <ellipse cx="614" cy="-33" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="614" y="-29.3">1</text>
# </g>
# <!-- 1&#45;&gt;0 -->
# <g class="edge" id="edge3"><title>1-&gt;0</title>
# <path d="M597.589,-25.5437C591.583,-22.8653 584.574,-20.0124 578,-18 537.326,-5.54962 526.537,-2.55351e-15 484,-0 195.5,-0 195.5,-0 195.5,-0 148.071,-2.88658e-15 134.861,-5.69019 92,-26 86.3951,-28.6559 80.7926,-32.2752 75.7651,-35.9691" fill="none" stroke="black"/>
# <polygon fill="black" points="70.1618,-40.2865 73.7842,-33.5188 72.9343,-38.1503 75.7068,-36.0141 75.7068,-36.0141 75.7068,-36.0141 72.9343,-38.1503 77.6293,-38.5093 70.1618,-40.2865 70.1618,-40.2865" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="315" y="-18.8">p0 &amp; !p1</text>
# <text fill="#f17cb0" font-family="Lato" font-size="14.00" text-anchor="start" x="334.5" y="-3.8">❶</text>
# </g>
# <!-- 1&#45;&gt;1 -->
# <g class="edge" id="edge5"><title>1-&gt;1</title>
# <path d="M603.292,-47.7917C599.806,-58.4165 603.375,-69 614,-69 622.135,-69 626.134,-62.7961 625.997,-55.1197" fill="none" stroke="black"/>
# <polygon fill="black" points="624.708,-47.7917 629.023,-54.1403 625.314,-51.2388 625.92,-54.6859 625.92,-54.6859 625.92,-54.6859 625.314,-51.2388 622.818,-55.2315 624.708,-47.7917 624.708,-47.7917" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="584.5" y="-87.8">!p0 &amp; !p1</text>
# <text fill="#faa43a" font-family="Lato" font-size="14.00" text-anchor="start" x="606" y="-72.8">❷</text>
# </g>
# <!-- 4 -->
# <g class="node" id="node5"><title>4</title>
# <ellipse cx="483" cy="-76" fill="#ffffaa" rx="18" ry="18" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="middle" x="483" y="-72.3">4</text>
# </g>
# <!-- 1&#45;&gt;4 -->
# <g class="edge" id="edge4"><title>1-&gt;4</title>
# <path d="M601.683,-46.226C595.39,-52.6763 587.018,-59.9085 578,-64 555.814,-74.0655 527.843,-76.5015 508.202,-76.7666" fill="none" stroke="black"/>
# <polygon fill="black" points="501.112,-76.7733 508.109,-73.6166 504.612,-76.7699 508.112,-76.7666 508.112,-76.7666 508.112,-76.7666 504.612,-76.7699 508.115,-79.9166 501.112,-76.7733 501.112,-76.7733" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="521" y="-94.8">!p0 &amp; p1</text>
# <text fill="#f17cb0" font-family="Lato" font-size="14.00" text-anchor="start" x="540.5" y="-79.8">❶</text>
# </g>
# <!-- 4&#45;&gt;1 -->
# <g class="edge" id="edge10"><title>4-&gt;1</title>
# <path d="M491.545,-59.6099C497.391,-49.0368 506.592,-36.1502 519,-30 541.019,-19.0855 569.641,-22.0424 589.489,-26.3324" fill="none" stroke="black"/>
# <polygon fill="black" points="596.376,-27.95 588.841,-29.4159 592.969,-27.1496 589.561,-26.3493 589.561,-26.3493 589.561,-26.3493 592.969,-27.1496 590.282,-23.2828 596.376,-27.95 596.376,-27.95" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="519" y="-48.8">!p0 &amp; !p1</text>
# <text fill="#f17cb0" font-family="Lato" font-size="14.00" text-anchor="start" x="540.5" y="-33.8">❶</text>
# </g>
# <!-- 2&#45;&gt;0 -->
# <g class="edge" id="edge7"><title>2-&gt;0</title>
# <path d="M324.716,-80.2186C316.432,-82.089 306.255,-84.0735 297,-85 206.066,-94.1034 179.849,-94.1862 92,-69 87.4829,-67.7049 82.8363,-65.8585 78.4642,-63.8559" fill="none" stroke="black"/>
# <polygon fill="black" points="71.8778,-60.6373 79.55,-60.8805 75.0224,-62.174 78.167,-63.7107 78.167,-63.7107 78.167,-63.7107 75.0224,-62.174 76.784,-66.5408 71.8778,-60.6373 71.8778,-60.6373" stroke="black"/>
# <text font-family="Lato" font-size="14.00" text-anchor="start" x="169" y="-108.8">p0 &amp; !p1</text>
# <text fill="#f17cb0" font-family="Lato" font-size="14.00" text-anchor="start" x="188.5" y="-93.8">❶</text>
# </g>
# <!-- 2&#45;&gt;4 -->
# <g class="edge" id="edge6"><title>2-&gt;4</title>
# <path d="M360.761,-76C385.257,-76 430.207,-76 457.956,-76" fill="none" stroke="black"/>
# <polygon fill="black" points="464.956,-76 457.957,-79.1501 461.456,-76 457.956,-76.0001 457.956,-76.0001 457.956,-76.0001 461.456,-76 457.956,-72.8501 464.956,-76 464.956,-76" stroke="black"/>
# <text font-famil
